# %% [markdown]
# # MVP EPL Regression

# %% [markdown]
# ## English Premier League Player Valuation

# %% [markdown]
# #### Goal:
#
# The goal of the project is to evaluate the 'Market Value' of a player in the English Premier League given the attribites of the player.

# %%
from IPython.display import Image
Image("mvp_r2_coef_table.png")

# %% [markdown]
# To start, I have approached 2 websites in order to collect data with the most valuable and relatable attributes(features) for each player.
#
# www.fbref.com
# www.tansfermarket.us
#
#
# In order to grab data as many as possible, data for the seasons of 2019-2020 and 2020-2021 have been collected from both websites.

# %% [markdown]
# As shown in the OLS regression results:
#
# The R^2 for the data is .462 which is not ideal. That can be addressed by having more data and adding more features to our dataframe.
# The best realation between the features and the our main subject 'Market Value' is to be 'Mp', 'Starts' , 'Min' which I belive its shown with respect in the  P column. while I do belive there is some colinearity going on between some features that I'm going to be addressing them for the final project.
